# %% [markdown]
# # iQuHack 2026 - Quantum Entanglement Distillation Game
#
# In this game, you design quantum circuits to distill noisy Bell pairs and claim edges in a network.
#
# **Game Flow**: Register -> Select Starting Node -> Design Circuits -> Claim Edges -> Score Points

# %%
from client import GameClient
from visualization import GraphTool
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
import json
from pathlib import Path

# %% [markdown]
# ## Session Management
#
# Save/load your session to avoid re-registering.

# %%
SESSION_FILE = Path("session.json")

def save_session(client):
    if client.api_token:
        with open(SESSION_FILE, "w") as f:
            json.dump({"api_token": client.api_token, "player_id": client.player_id, "name": client.name}, f)
        print(f"Session saved.")

def load_session():
    if not SESSION_FILE.exists():
        return None
    with open(SESSION_FILE) as f:
        data = json.load(f)
    client = GameClient(api_token=data.get("api_token"))
    client.player_id = data.get("player_id")
    client.name = data.get("name")
    status = client.get_status()
    if status:
        print(f"Resumed: {client.player_id} | Score: {status.get('score', 0)} | Budget: {status.get('budget', 0)}")
        return client
    return None

# %%
# Try to resume existing session
client = load_session()

if not client:
    print("No saved session. Register below.")
# Out:
# Resumed: Ram_23356_new_version1 | Score: 0 | Budget: 40

# %% [markdown]
# ## Step 1: Register
#
# Skip this if you resumed a session above.

# %%
if client and client.api_token:
    print(f"Already registered as {client.player_id}")
else:
    client = GameClient()
    
    # CHANGE THESE to your unique values
    PLAYER_ID = "Ram_23356_new_version1"
    PLAYER_NAME = "Ramachandran SS"
    
    result = client.register(PLAYER_ID, PLAYER_NAME, location=input("remote or in_person: ").strip())
    
    if result.get("ok"):
        print(f"Registered! Token: {client.api_token[:20]}...")
        candidates = result["data"].get("starting_candidates", [])
        print(f"\nStarting candidates ({len(candidates)}):")
        for c in candidates:
            print(f"  - {c['node_id']}: {c['utility_qubits']} qubits, +{c['bonus_bell_pairs']} bonus")
        save_session(client)
    else:
        print(f"Failed: {result.get('error', {}).get('message')}")
# Out:
# Already registered as Ram_23356_new_version1

# %% [markdown]
# ## Step 2: Select Starting Node

# %%
status = client.get_status()

if status.get('starting_node'):
    print(f"Starting node: {status['starting_node']}")
    print(f"Budget: {status['budget']} | Score: {status['score']}")
else:
    print("Select a starting node from the candidates shown above.")
    # Uncomment and modify:
    result = client.select_starting_node("Graz, Austria")  # Kharagpur, India
    print(result)
# Out:
# Select a starting node from the candidates shown above.
# {'ok': True, 'data': {'success': True, 'starting_node': 'Graz, Austria', 'score': 46, 'budget': 40}}

# %%
graph = client.get_graph() 
edges = graph['edges']
print(edges[0:5])
# Out:
# [{'edge_id': ['College Park, MD', 'Washington, DC'], 'base_threshold': 0.9, 'difficulty_rating': 1, 'successful_attempts': 1}, {'edge_id': ['Baltimore, MD', 'College Park, MD'], 'base_threshold': 0.9, 'difficulty_rating': 1, 'successful_attempts': 1}, {'edge_id': ['College Park, MD', 'Richmond, VA'], 'base_threshold': 0.9, 'difficulty_rating': 2, 'successful_attempts': 0}, {'edge_id': ['Charlottesville, VA', 'College Park, MD'], 'base_threshold': 0.9, 'difficulty_rating': 2, 'successful_attempts': 0}, {'edge_id': ['Bothell, WA', 'Seattle, WA'], 'base_threshold': 0.9, 'difficulty_rating': 1, 'successful_attempts': 0}]

# %%
print(len(edges))
# Out:
# 1057

# %%
# Temp code Graph algorithm
import networkx as nx

G = nx.Graph()
start_nodes = ['Graz, Austria','Hanoi, Vietnam','Uppsala, Sweden','Haifa, Israel']

for e in edges:
    n1, n2 = e["edge_id"]
    difficulty = e["difficulty_rating"]
    G.add_edge(n1, n2, weight=difficulty)

# %%
from qiskit.circuit.classical import expr
import numpy as np
##### DEJMPS protocol
def create_distillation_circuit_DEJMPS():
    """Example distillation circuit template for 2 Bell pairs."""
    qr = QuantumRegister(4, 'q')  # 4 qubits for 2 Bell pairs
    cr = ClassicalRegister(3, 'c')  # Classical bits for measurements + flag
    qc = QuantumCircuit(qr, cr)
    
    # TODO: Add your distillation operations here
    # Qubit layout for N=2:
    #   q0, q3: Ancilla pair (to be measured)
    #   q1, q2: Data pair (output)
    qc.rx(np.pi/2, qr[0])
    qc.rx(np.pi/2, qr[1])

    qc.rx(-np.pi/2, qr[2])
    qc.rx(-np.pi/2, qr[3])
    
    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.measure(qr[0],cr[0])
    qc.measure(qr[3],cr[1])

    qc.store(cr[2], expr.bit_xor(cr[0], cr[1]))
    
    return qc

# %%
#####  BBPSSW protocol - 2 Bell pairs
def create_distillation_circuit_BBPSSW():
    """Example distillation circuit template for 2 Bell pairs."""
    qr = QuantumRegister(4, 'q')  # 4 qubits for 2 Bell pairs
    cr = ClassicalRegister(3, 'c')  # Classical bits for measurements + flag
    qc = QuantumCircuit(qr, cr)
    
    # TODO: Add your distillation operations here
    # Qubit layout for N=2:
    #   q0, q3: Ancilla pair (to be measured)
    #   q1, q2: Data pair (output)
    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.measure(qr[0],cr[0])
    qc.measure(qr[3],cr[1])

    qc.store(cr[2], expr.bit_xor(cr[0], cr[1]))
    
    return qc

# %%
### Updated DEJMPS with 2 rounds
def create_distillation_circuit_DEJMPS2():
    """Example distillation circuit template for 2 Bell pairs."""
    qr = QuantumRegister(4, 'q')  # 4 qubits for 2 Bell pairs
    cr = ClassicalRegister(3, 'c')  # Classical bits for measurements + flag
    qc = QuantumCircuit(qr, cr)
    
    # TODO: Add your distillation operations here
    # Qubit layout for N=2:
    #   q0, q3: Ancilla pair (to be measured)
    #   q1, q2: Data pair (output)
    
    qc.h(qr[0])
    qc.h(qr[1])
    qc.h(qr[2])
    qc.h(qr[3])
    
    qc.rx(np.pi/2, qr[0])
    qc.rx(np.pi/2, qr[1])

    qc.rx(-np.pi/2, qr[2])
    qc.rx(-np.pi/2, qr[3])
    
    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])



    qc.h(qr[0])
    qc.h(qr[1])
    qc.h(qr[2])
    qc.h(qr[3])
    
    qc.rx(np.pi/2, qr[0])
    qc.rx(np.pi/2, qr[1])

    qc.rx(-np.pi/2, qr[2])
    qc.rx(-np.pi/2, qr[3])
    
    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.measure(qr[0],cr[0])
    qc.measure(qr[3],cr[1])

    qc.store(cr[2], expr.bit_xor(cr[0], cr[1]))
    
    return qc

# %%
import heapq

visited = set()

def dijkstra_reachable_nodes(G, start):
    """
    Return all nodes reachable from `start` using only edges
    with difficulty 1 or 2.
    """
    allowed = {1, 2, 3} 
    pq = [(0, start)]  # (cost, node)

    result = client.select_starting_node(start)  # Kharagpur, India
    print(result)
    
    while pq:
        cost, node = heapq.heappop(pq)
        # print(node)
        if node in visited:
            continue
        visited.add(node)

        claimable = client.get_claimable_edges()
        claimable_set = {tuple(e["edge_id"]) for e in claimable}
        # print(claimable_set)
        
        for neighbor in G.neighbors(node):
            diff = G[node][neighbor]["weight"]
            # print(node)
            # print(neighbor)
            # print(diff)
            if diff in allowed and neighbor not in visited:
                heapq.heappush(pq, (diff, neighbor))
                if(diff == 1):
                    edge_id = tuple((node,neighbor))
                    
                
                    circuit = create_distillation_circuit_DEJMPS2()
                    num_bell_pairs = 2
                    flag_bit = 2  # Classical bit for post-selection (keep when flag=0)
                    edge_id_temp = (node, neighbor) 
                    reverse_edge_id = (neighbor, node)
                    if edge_id_temp not in claimable_set and reverse_edge_id not in claimable_set:
                        continue
                    result = client.claim_edge(edge_id, circuit, flag_bit, num_bell_pairs)
                    
                    if result.get("ok"):
                        data = result["data"]
                        print(f"Success: {data.get('success')}")
                        print(f"Fidelity: {data.get('fidelity', 0):.4f} (threshold: {data.get('threshold', 0):.4f})")
                        print(f"Success probability: {data.get('success_probability', 0):.4f}")
                    else:
                        print(f"Error: {result.get('error', {}).get('message')}")

                if(diff == 2):
                    edge_id = tuple((node,neighbor))
                    
                    
                    circuit = create_distillation_circuit_DEJMPS2()
                    num_bell_pairs = 2
                    flag_bit = 2  # Classical bit for post-selection (keep when flag=0)
                    edge_id_temp = (node, neighbor) 
                    reverse_edge_id = (neighbor, node)
                    if edge_id_temp not in claimable_set and reverse_edge_id not in claimable_set:
                        continue
                    result = client.claim_edge(edge_id, circuit, flag_bit, num_bell_pairs)
                    
                    if result.get("ok"):
                        data = result["data"]
                        print(f"Success: {data.get('success')}")
                        print(f"Fidelity: {data.get('fidelity', 0):.4f} (threshold: {data.get('threshold', 0):.4f})")
                        print(f"Success probability: {data.get('success_probability', 0):.4f}")
                    else:
                        print(f"Error: {result.get('error', {}).get('message')}")

                if(diff == 3):
                    edge_id = tuple((node,neighbor))
                    
                    
                    circuit = create_distillation_circuit_DEJMPS2()
                    num_bell_pairs = 2
                    flag_bit = 2  # Classical bit for post-selection (keep when flag=0)
                    edge_id_temp = (node, neighbor) 
                    reverse_edge_id = (neighbor, node)
                    if edge_id_temp not in claimable_set and reverse_edge_id not in claimable_set:
                        continue
                    result = client.claim_edge(edge_id, circuit, flag_bit, num_bell_pairs)
                    
                    if result.get("ok"):
                        data = result["data"]
                        print(f"Success: {data.get('success')}")
                        print(f"Fidelity: {data.get('fidelity', 0):.4f} (threshold: {data.get('threshold', 0):.4f})")
                        print(f"Success probability: {data.get('success_probability', 0):.4f}")
                    else:
                        print(f"Error: {result.get('error', {}).get('message')}")

# dijkstra_reachable_nodes(G,start_nodes[0])

# %%
dijkstra_reachable_nodes(G,start_nodes[0])
# Out:
# {'ok': True, 'data': {'success': True, 'starting_node': 'Graz, Austria', 'score': 46, 'budget': 40}}
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: False
# Fidelity: 0.8000 (threshold: 0.9000)
# Success probability: 0.8000
# Success: True
# Fidelity: 0.9698 (threshold: 0.9000)
# Success probability: 0.7450
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dijkstra_reachable_nodes(G,start_nodes[0])
#
# Cell In[13], line 45, in dijkstra_reachable_nodes(G, start)
#      43 if edge_id_temp not in claimable_set and reverse_edge_id not in claimable_set:
#      44     continue
# ---> 45 result = client.claim_edge(edge_id, circuit, flag_bit, num_bell_pairs)
#      47 if result.get("ok"):
#      48     data = result["data"]
#
# File ~/2026-IonQ/client.py:108, in GameClient.claim_edge(self, edge, circuit, flag_bit, num_bell_pairs)
#      99     return {"ok": False, "error": {"code": "NOT_REGISTERED", "message": "Not registered"}}
#     101 payload = {
#     102     "player_id": self.player_id,
#     103     "edge": [edge[0], edge[1]],
#    (...)    106     "flag_bit": int(flag_bit),
#     107 }
# --> 108 return self._post("/v1/claim_edge", payload)
#
# File ~/2026-IonQ/client.py:35, in GameClient._post(self, path, payload, require_auth)
#      33     return {"ok": False, "error": {"code": "NO_TOKEN", "message": "No API token. Register first."}}
#      34 r = requests.post(f"{self.base_url}{path}", json=payload, headers=self._headers(), timeout=None)
# ---> 35 r.raise_for_status()
#      36 return r.json()
#
# File ~/.qbraid/environments/pgwb/pyenv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://demo-entanglement-distillation-qfhvrahfcq-uc.a.run.app/v1/claim_edge

# %% [markdown]
# ## Step 3: Explore the Network

# %%
client.print_status()
# Out:
# ==================================================
# Player: Ram_23356_new_version1 (Ramachandran SS)
# Score: 83 | Budget: 1 bell pairs
# Active: Yes
# Starting node: Graz, Austria
# Owned: 35 nodes, 42 edges
# Claimable edges: 26
#   - ['Basel, Switzerland', 'Zurich, Switzerland']: threshold=0.90, difficulty=1
#   - ['Basel, Switzerland', 'Strasbourg, France']: threshold=0.90, difficulty=1
#   - ['Bern, Switzerland', 'Zurich, Switzerland']: threshold=0.90, difficulty=1
#   ... and 23 more
# ==================================================

# %%
# Visualize the network (focused around your nodes)
viz = GraphTool(client.get_cached_graph())
owned = set(client.get_status().get('owned_nodes', []))
viz.render(owned)

# %% [markdown]
# ## Step 4: Design a Distillation Circuit
#
# For N Bell pairs, qubits are paired outside-in:
# - Pair 0: qubits {0, 2N-1}
# - Pair 1: qubits {1, 2N-2}
# - ...
# - Final pair: qubits {N-1, N}
#
# Design a circuit that improves fidelity through LOCC operations.

# %%
from qiskit.circuit.classical import expr
import numpy as np
##### DEJMPS protocol
def create_distillation_circuit():
    """Example distillation circuit template for 2 Bell pairs."""
    qr = QuantumRegister(4, 'q')  # 4 qubits for 2 Bell pairs
    cr = ClassicalRegister(3, 'c')  # Classical bits for measurements + flag
    qc = QuantumCircuit(qr, cr)
    
    # TODO: Add your distillation operations here
    # Qubit layout for N=2:
    #   q0, q3: Ancilla pair (to be measured)
    #   q1, q2: Data pair (output)
    qc.rx(np.pi/2, qr[0])
    qc.rx(np.pi/2, qr[1])

    qc.rx(-np.pi/2, qr[2])
    qc.rx(-np.pi/2, qr[3])
    
    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.measure(qr[0],cr[0])
    qc.measure(qr[3],cr[1])

    qc.store(cr[2], expr.bit_xor(cr[0], cr[1]))
    
    return qc

circuit = create_distillation_circuit()
print(circuit.draw(output='text'))
# Out:
#      ┌─────────┐ ┌───┐┌─┐
# q_0: ┤ Rx(π/2) ├─┤ X ├┤M├───
#      ├─────────┤ └─┬─┘└╥┘
# q_1: ┤ Rx(π/2) ├───■───╫────
#      ├─────────┴┐      ║
# q_2: ┤ Rx(-π/2) ├──■───╫────
#      ├──────────┤┌─┴─┐ ║ ┌─┐
# q_3: ┤ Rx(-π/2) ├┤ X ├─╫─┤M├
#      └──────────┘└───┘ ║ └╥┘
# c: 3/══════════════════╩══╩═
#                        0  1

# %%
from qiskit.circuit.classical import expr
import numpy as np
#####  BBPSSW protocol - 2 Bell pairs
def create_distillation_circuit():
    """Example distillation circuit template for 2 Bell pairs."""
    qr = QuantumRegister(4, 'q')  # 4 qubits for 2 Bell pairs
    cr = ClassicalRegister(3, 'c')  # Classical bits for measurements + flag
    qc = QuantumCircuit(qr, cr)
    
    # TODO: Add your distillation operations here
    # Qubit layout for N=2:
    #   q0, q3: Ancilla pair (to be measured)
    #   q1, q2: Data pair (output)
    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.cx(qr[1],qr[0])
    qc.cx(qr[2],qr[3])

    qc.measure(qr[0],cr[0])
    qc.measure(qr[3],cr[1])

    qc.store(cr[2], expr.bit_xor(cr[0], cr[1]))
    
    return qc

circuit = create_distillation_circuit()
print(circuit.draw(output='text'))
# Out:
#      ┌───┐┌───┐┌───┐┌─┐
# q_0: ┤ X ├┤ X ├┤ X ├┤M├───
#      └─┬─┘└─┬─┘└─┬─┘└╥┘
# q_1: ──■────■────■───╫────
#                      ║
# q_2: ──■────■────■───╫────
#      ┌─┴─┐┌─┴─┐┌─┴─┐ ║ ┌─┐
# q_3: ┤ X ├┤ X ├┤ X ├─╫─┤M├
#      └───┘└───┘└───┘ ║ └╥┘
# c: 3/════════════════╩══╩═
#                      0  1

# %%
# from qiskit.circuit.classical import expr
# import numpy as np
# #####  BBPSSW protocol -  3 Bell pairs - FIND A 8 qubit node
# def create_distillation_circuit():
#     """Example distillation circuit template for 3 Bell pairs."""
#     qr = QuantumRegister(6, 'q')  # 6 qubits for 3 Bell pairs
#     cr = ClassicalRegister(5, 'c')  # Classical bits for measurements + flag
#     qc = QuantumCircuit(qr, cr)
    
#     # TODO: Add your distillation operations here
#     # Qubit layout for N=2:
#     #   q0, q3: Ancilla pair (to be measured)
#     #   q1, q2: Data pair (output)
#     qc.cx(qr[2],qr[0])
#     qc.cx(qr[2],qr[1])
    
#     qc.cx(qr[3],qr[5])
#     qc.cx(qr[3],qr[4])

#     qc.measure(qr[0],cr[0])
#     qc.measure(qr[1],cr[1])
#     qc.measure(qr[5],cr[2])
#     qc.measure(qr[4],cr[3])

#     qc.store(cr[4],expr.bit_xor(cr[0], cr[1]))
    
#     return qc

# circuit = create_distillation_circuit()
# print(circuit.draw(output='text'))
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ X ├─────┤M├──────
#      └─┬─┘┌───┐└╥┘┌─┐
# q_1: ──┼──┤ X ├─╫─┤M├───
#        │  └─┬─┘ ║ └╥┘
# q_2: ──■────■───╫──╫────
#                 ║  ║
# q_3: ──■────■───╫──╫────
#        │  ┌─┴─┐ ║  ║ ┌─┐
# q_4: ──┼──┤ X ├─╫──╫─┤M├
#      ┌─┴─┐└┬─┬┘ ║  ║ └╥┘
# q_5: ┤ X ├─┤M├──╫──╫──╫─
#      └───┘ └╥┘  ║  ║  ║
# c: 5/═══════╩═══╩══╩══╩═
#             2   0  1  3

# %%
# from qiskit.circuit.classical import expr
# import numpy as np
# #####  DEJMPS protocol -  3 Bell pairs - FIND A 8 qubit node
# def create_distillation_circuit():
#     """Example distillation circuit template for 3 Bell pairs."""
#     qr = QuantumRegister(6, 'q')  # 6 qubits for 3 Bell pairs
#     cr = ClassicalRegister(5, 'c')  # Classical bits for measurements + flag
#     qc = QuantumCircuit(qr, cr)
    
#     # TODO: Add your distillation operations here
#     # Qubit layout for N=2:
#     #   q0, q3: Ancilla pair (to be measured)
#     #   q1, q2: Data pair (output)
#     qc.rx(np.pi/2, qr[0])
#     qc.rx(np.pi/2, qr[1])
#     qc.rx(np.pi/2, qr[2])

#     qc.rx(-np.pi/2, qr[3])
#     qc.rx(-np.pi/2, qr[4])
#     qc.rx(-np.pi/2, qr[5])
    
#     qc.cx(qr[2],qr[0])
#     qc.cx(qr[2],qr[1])
    
#     qc.cx(qr[3],qr[5])
#     qc.cx(qr[3],qr[4])

#     qc.measure(qr[0],cr[0])
#     qc.measure(qr[1],cr[1])
#     qc.measure(qr[5],cr[2])
#     qc.measure(qr[4],cr[3])

#     qc.store(cr[4],expr.bit_xor(cr[0], cr[1]))
    
#     return qc

# circuit = create_distillation_circuit()
# print(circuit.draw(output='text'))
# Out:
#      ┌─────────┐ ┌───┐     ┌─┐
# q_0: ┤ Rx(π/2) ├─┤ X ├─────┤M├──────
#      ├─────────┤ └─┬─┘┌───┐└╥┘┌─┐
# q_1: ┤ Rx(π/2) ├───┼──┤ X ├─╫─┤M├───
#      ├─────────┤   │  └─┬─┘ ║ └╥┘
# q_2: ┤ Rx(π/2) ├───■────■───╫──╫────
#      ├─────────┴┐           ║  ║
# q_3: ┤ Rx(-π/2) ├──■────■───╫──╫────
#      ├──────────┤  │  ┌─┴─┐ ║  ║ ┌─┐
# q_4: ┤ Rx(-π/2) ├──┼──┤ X ├─╫──╫─┤M├
#      ├──────────┤┌─┴─┐└┬─┬┘ ║  ║ └╥┘
# q_5: ┤ Rx(-π/2) ├┤ X ├─┤M├──╫──╫──╫─
#      └──────────┘└───┘ └╥┘  ║  ║  ║
# c: 5/═══════════════════╩═══╩══╩══╩═
#                         2   0  1  3

# %%
# from qiskit.circuit.classical import expr
# import numpy as np
# #####  LOCNET protocol -  2 Bell pairs IN PROGRESS
# def create_distillation_circuit():
#     """Example distillation circuit template for 3 Bell pairs."""
#     qr = QuantumRegister(4, 'q')  # 4 qubits for 2 Bell pairs
#     cr = ClassicalRegister(3, 'c')  # Classical bits for measurements + flag
#     qc = QuantumCircuit(qr, cr)
    
#     # TODO: Add your distillation operations here
#     # Qubit layout for N=2:
#     #   q0, q3: Ancilla pair (to be measured)
#     #   q1, q2: Data pair (output)
#     qc.rx(np.pi/2, qr[0])
#     qc.rx(np.pi/2, qr[1])
#     qc.rx(np.pi/2, qr[2])

#     qc.rx(-np.pi/2, qr[3])
#     qc.rx(-np.pi/2, qr[4])
#     qc.rx(-np.pi/2, qr[5])
    
#     qc.cx(qr[2],qr[0])
#     qc.cx(qr[2],qr[1])
    
#     qc.cx(qr[3],qr[5])
#     qc.cx(qr[3],qr[4])

#     qc.measure(qr[0],cr[0])
#     qc.measure(qr[1],cr[1])
#     qc.measure(qr[5],cr[2])
#     qc.measure(qr[4],cr[3])

#     qc.store(cr[4],expr.bit_xor(cr[0], cr[1]))
    
#     return qc

# circuit = create_distillation_circuit()
# print(circuit.draw(output='text'))

# %% [markdown]
# ## Step 5: Claim an Edge

# %%
# Find claimable edges
claimable = client.get_claimable_edges()
claimable_sorted = sorted(claimable, key=lambda e: (e['difficulty_rating'], e['base_threshold']))

print(f"Claimable edges ({len(claimable)}):")
for edge in claimable_sorted[:5]:
    print(f"  {edge['edge_id']} - threshold: {edge['base_threshold']:.3f}, difficulty: {edge['difficulty_rating']}")
# Out:
# Claimable edges (15):
#   ['Basel, Switzerland', 'Zurich, Switzerland'] - threshold: 0.900, difficulty: 1
#   ['Bern, Switzerland', 'Zurich, Switzerland'] - threshold: 0.900, difficulty: 1
#   ['Strasbourg, France', 'Zurich, Switzerland'] - threshold: 0.900, difficulty: 1
#   ['Bonn, Germany', 'Frankfurt, Germany'] - threshold: 0.900, difficulty: 1
#   ['Cologne, Germany', 'Frankfurt, Germany'] - threshold: 0.900, difficulty: 1

# %%
# Claim an edge
if claimable:
    target = claimable_sorted[0]  # Easiest edge
    edge_id = tuple(target['edge_id'])
    print(edge_id)
    circuit = create_distillation_circuit()
    num_bell_pairs = 2
    flag_bit = 2  # Classical bit for post-selection (keep when flag=0)
    
    print(f"Claiming {edge_id} (threshold: {target['base_threshold']:.3f})...")
    
    result = client.claim_edge(edge_id, circuit, flag_bit, num_bell_pairs)
    
    if result.get("ok"):
        data = result["data"]
        print(f"Success: {data.get('success')}")
        print(f"Fidelity: {data.get('fidelity', 0):.4f} (threshold: {data.get('threshold', 0):.4f})")
        print(f"Success probability: {data.get('success_probability', 0):.4f}")
    else:
        print(f"Error: {result.get('error', {}).get('message')}")
# Out:
# ('Basel, Switzerland', 'Zurich, Switzerland')
# Claiming ('Basel, Switzerland', 'Zurich, Switzerland') (threshold: 0.900)...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[18], line 12
#       8 flag_bit = 2  # Classical bit for post-selection (keep when flag=0)
#      10 print(f"Claiming {edge_id} (threshold: {target['base_threshold']:.3f})...")
# ---> 12 result = client.claim_edge(edge_id, circuit, flag_bit, num_bell_pairs)
#      14 if result.get("ok"):
#      15     data = result["data"]
#
# File ~/2026-IonQ/client.py:108, in GameClient.claim_edge(self, edge, circuit, flag_bit, num_bell_pairs)
#      99     return {"ok": False, "error": {"code": "NOT_REGISTERED", "message": "Not registered"}}
#     101 payload = {
#     102     "player_id": self.player_id,
#     103     "edge": [edge[0], edge[1]],
#    (...)    106     "flag_bit": int(flag_bit),
#     107 }
# --> 108 return self._post("/v1/claim_edge", payload)
#
# File ~/2026-IonQ/client.py:35, in GameClient._post(self, path, payload, require_auth)
#      33     return {"ok": False, "error": {"code": "NO_TOKEN", "message": "No API token. Register first."}}
#      34 r = requests.post(f"{self.base_url}{path}", json=payload, headers=self._headers(), timeout=None)
# ---> 35 r.raise_for_status()
#      36 return r.json()
#
# File ~/.qbraid/environments/pgwb/pyenv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://demo-entanglement-distillation-qfhvrahfcq-uc.a.run.app/v1/claim_edge

# %% [markdown]
# ## Step 6: Check Progress

# %%
client.print_status()
# Out:
# ==================================================
# Player: Ram_23356_new (Ramachandran SS)
# Score: 21 | Budget: 20 bell pairs
# Active: Yes
# Starting node: Istanbul, Turkey
# Owned: 6 nodes, 9 edges
# Claimable edges: 4
#   - ['Bucharest, Romania', 'Lviv, Ukraine']: threshold=0.90, difficulty=3
#   - ['Ankara, Turkey', 'Istanbul, Turkey']: threshold=0.90, difficulty=3
#   - ['Ankara, Turkey', 'Izmir, Turkey']: threshold=0.90, difficulty=3
#   ... and 1 more
# ==================================================

# %%
# View leaderboard
leaderboard = client.get_leaderboard()["leaderboard"]
print("Leaderboard:")
for i, p in enumerate(leaderboard[:10]):
    print(f"{i+1}. {p.get('player_id', 'Unknown'):20} Score: {p.get('score', 0)}")
# Out:
# Leaderboard:
# 1. bloch_distiller      Score: 92
# 2. Ram_23356_new_version1 Score: 83
# 3. test_claude_1523b    Score: 70
# 4. EEE3                 Score: 60
# 5. okaywillisveryawakenow Score: 51
# 6. Ram_23356_new        Score: 48
# 7. jokkkk               Score: 43
# 8. willhashadalotofcaffeine Score: 42
# 9. roger                Score: 40
# 10. willhatesclaude      Score: 36

# %% [markdown]
# ## Tips
#
# - **Failed attempts are free** - only successful claims cost bell pairs
# - **More bell pairs** can improve fidelity but cost more budget
# - **Vertex rewards** are competitive - top players by claim strength earn rewards
# - **Budget management** is key - if budget reaches 0, you're eliminated
#
# Good luck!

# %%
# # Restart game (uncomment to use)
result = client.restart()
print(result)
# Out:
# {'ok': True, 'data': {'success': True, 'budget': 40, 'is_active': True, 'starting_candidates': [{'node_id': 'Graz, Austria', 'utility_qubits': 2, 'bonus_bell_pairs': 0, 'capacity': 5, 'latitude': 47.0707, 'longitude': 15.4395}, {'node_id': 'Hanoi, Vietnam', 'utility_qubits': 4, 'bonus_bell_pairs': 0, 'capacity': 6, 'latitude': 21.0285, 'longitude': 105.8542}, {'node_id': 'Uppsala, Sweden', 'utility_qubits': 1, 'bonus_bell_pairs': 1, 'capacity': 4, 'latitude': 59.8586, 'longitude': 17.6389}, {'node_id': 'Haifa, Israel', 'utility_qubits': 2, 'bonus_bell_pairs': 1, 'capacity': 6, 'latitude': 32.794, 'longitude': 34.9896}]}}

# %%
graph = client.get_graph() 
edges = graph['edges']
print(edges[0:5])
# Out:
# [{'edge_id': ['College Park, MD', 'Washington, DC'], 'base_threshold': 0.9, 'difficulty_rating': 1, 'successful_attempts': 19}, {'edge_id': ['Baltimore, MD', 'College Park, MD'], 'base_threshold': 0.9, 'difficulty_rating': 1, 'successful_attempts': 28}, {'edge_id': ['College Park, MD', 'Richmond, VA'], 'base_threshold': 0.9, 'difficulty_rating': 2, 'successful_attempts': 4}, {'edge_id': ['Charlottesville, VA', 'College Park, MD'], 'base_threshold': 0.9, 'difficulty_rating': 2, 'successful_attempts': 6}, {'edge_id': ['Bothell, WA', 'Seattle, WA'], 'base_threshold': 0.9, 'difficulty_rating': 1, 'successful_attempts': 6}]

# %%
# Temp code Graph algorithm
import networkx as nx

G = nx.Graph()
start_nodes = ['Kharagpur, India','Oslo, Norway','Zagreb, Croatia','Seoul, South Korea']

for e in edges:
    n1, n2 = e["edge_id"]
    difficulty = e["difficulty_rating"]
    G.add_edge(n1, n2, weight=difficulty)

# %%
import heapq

def dijkstra_reachable_nodes(G, start):
    """
    Return all nodes reachable from `start` using only edges
    with difficulty 1 or 2.
    """
    allowed = {1, 2}
    visited = set()
    pq = [(0, start)]  # (cost, node)

    while pq:
        cost, node = heapq.heappop(pq)
        print(node)
        if node in visited:
            continue
        visited.add(node)

        for neighbor in G.neighbors(node):
            diff = G[node][neighbor]["weight"]
            if diff in allowed and neighbor not in visited:
                heapq.heappush(pq, (diff, neighbor))

    return visited

dijkstra_reachable_nodes(G,start_nodes[2])
# Out:
# Zagreb, Croatia
# Graz, Austria
# Ljubljana, Slovenia
# Ljubljana, Slovenia
# Vienna, Austria
# Bratislava, Slovakia
# Brno, Czechia
# Brno, Czechia
# Linz, Austria
# Salzburg, Austria
# Innsbruck, Austria
# Munich, Germany
# Munich, Germany
# Nuremberg, Germany
# Stuttgart, Germany
# Frankfurt, Germany
# Bonn, Germany
# Aachen, Germany
# Cologne, Germany
# Cologne, Germany
# Cologne, Germany
# Dortmund, Germany
# Dortmund, Germany
# Dusseldorf, Germany
# Dusseldorf, Germany
# Dusseldorf, Germany
# Dusseldorf, Germany
# Eindhoven, Netherlands
# Antwerp, Belgium
# Brussels, Belgium
# Essen, Germany
# Essen, Germany
# Essen, Germany
# Essen, Germany
# Ghent, Belgium
# Ghent, Belgium
# Heidelberg, Germany
# Heidelberg, Germany
# Leuven, Belgium
# Leuven, Belgium
# Leuven, Belgium
# Leuven, Belgium
# Lille, France
# Lille, France
# Lille, France
# Lille, France
# Luxembourg City
# Luxembourg City
# Luxembourg City
# Strasbourg, France
# Basel, Switzerland
# Bern, Switzerland
# Geneva, Switzerland
# Grenoble, France
# Lausanne, Switzerland
# Lausanne, Switzerland
# Lausanne, Switzerland
# Lyon, France
# Lyon, France
# Strasbourg, France
# Turin, Italy
# Milan, Italy
# Nice, France
# Marseille, France
# Montpellier, France
# Utrecht, Netherlands
# Amsterdam, Netherlands
# Delft, Netherlands
# Delft, Netherlands
# Groningen, Netherlands
# Bremen, Germany
# Groningen, Netherlands
# Hamburg, Germany
# Hanover, Germany
# Hanover, Germany
# Leiden, Netherlands
# Leiden, Netherlands
# Leiden, Netherlands
# Rotterdam, Netherlands
# Rotterdam, Netherlands
# Rotterdam, Netherlands
# Rotterdam, Netherlands
# Zurich, Switzerland
# Zurich, Switzerland
# Zurich, Switzerland
# Barcelona, Spain
# Berlin, Germany
# Leipzig, Germany
# Dresden, Germany
# Prague, Czechia
# Berlin, Germany
# Bologna, Italy
# Florence, Italy
# Bologna, Italy
# Bologna, Italy
# Bratislava, Slovakia
# Bratislava, Slovakia
# Bremen, Germany
# Budapest, Hungary
# Budapest, Hungary
# Budapest, Hungary
# Budapest, Hungary
# Dresden, Germany
# Dresden, Germany
# Florence, Italy
# Florence, Italy
# Frankfurt, Germany
# Hamburg, Germany
# Hanover, Germany
# Hanover, Germany
# Heidelberg, Germany
# Krakow, Poland
# Krakow, Poland
# Lausanne, Switzerland
# Leiden, Netherlands
# Leipzig, Germany
# Linz, Austria
# Linz, Austria
# Linz, Austria
# Lviv, Ukraine
# Lyon, France
# Marseille, France
# Marseille, France
# Milan, Italy
# Montpellier, France
# Montpellier, France
# Nice, France
# Nice, France
# Paris, France
# Paris, France
# Paris, France
# Paris, France
# Prague, Czechia
# Prague, Czechia
# Prague, Czechia
# Rennes, France
# Nantes, France
# Bordeaux, France
# Bilbao, Spain
# Madrid, Spain
# Rome, Italy
# Rome, Italy
# Salzburg, Austria
# Salzburg, Austria
# Southampton, UK
# Bristol, UK
# Birmingham, UK
# Cambridge, UK
# Cardiff, UK
# Cardiff, UK
# Cardiff, UK
# Liverpool, UK
# Leeds, UK
# London, UK
# London, UK
# Manchester, UK
# Manchester, UK
# Manchester, UK
# Newcastle, UK
# Edinburgh, UK
# Glasgow, UK
# Nottingham, UK
# Nottingham, UK
# Nottingham, UK
# Nottingham, UK
# Oxford, UK
# Oxford, UK
# Oxford, UK
# Oxford, UK
# Oxford, UK
# Oxford, UK
# Sheffield, UK
# Sheffield, UK
# Sheffield, UK
# Sheffield, UK
# Sheffield, UK
# Belfast, UK
# Dublin, Ireland
# Belfast, UK
# Belfast, UK
# Cork, Ireland
# Galway, Ireland
# Dublin, Ireland
# Edinburgh, UK
# Galway, Ireland
# Galway, Ireland
# Glasgow, UK
# Glasgow, UK
# London, UK
# Newcastle, UK
# Sheffield, UK
# Strasbourg, France
# Stuttgart, Germany
# Stuttgart, Germany
# Toulouse, France
# Toulouse, France
# Toulouse, France
# Toulouse, France
# Turin, Italy
# Turin, Italy
# Valencia, Spain
# Valencia, Spain
# Vienna, Austria
# Warsaw, Poland
# Gdansk, Poland
# Zurich, Switzerland
# Zurich, Switzerland
# Zurich, Switzerland
# {'Aachen, Germany',
#  'Amsterdam, Netherlands',
#  'Antwerp, Belgium',
#  'Barcelona, Spain',
#  'Basel, Switzerland',
#  'Belfast, UK',
#  'Berlin, Germany',
#  'Bern, Switzerland',
#  'Bilbao, Spain',
#  'Birmingham, UK',
#  'Bologna, Italy',
#  'Bonn, Germany',
#  'Bordeaux, France',
#  'Bratislava, Slovakia',
#  'Bremen, Germany',
#  'Bristol, UK',
#  'Brno, Czechia',
#  'Brussels, Belgium',
#  'Budapest, Hungary',
#  'Cambridge, UK',
#  'Cardiff, UK',
#  'Cologne, Germany',
#  'Cork, Ireland',
#  'Delft, Netherlands',
#  'Dortmund, Germany',
#  'Dresden, Germany',
#  'Dublin, Ireland',
#  'Dusseldorf, Germany',
#  'Edinburgh, UK',
#  'Eindhoven, Netherlands',
#  'Essen, Germany',
#  'Florence, Italy',
#  'Frankfurt, Germany',
#  'Galway, Ireland',
#  'Gdansk, Poland',
#  'Geneva, Switzerland',
#  'Ghent, Belgium',
#  'Glasgow, UK',
#  'Graz, Austria',
#  'Grenoble, France',
#  'Groningen, Netherlands',
#  'Hamburg, Germany',
#  'Hanover, Germany',
#  'Heidelberg, Germany',
#  'Innsbruck, Austria',
#  'Krakow, Poland',
#  'Lausanne, Switzerland',
#  'Leeds, UK',
#  'Leiden, Netherlands',
#  'Leipzig, Germany',
#  'Leuven, Belgium',
#  'Lille, France',
#  'Linz, Austria',
#  'Liverpool, UK',
#  'Ljubljana, Slovenia',
#  'London, UK',
#  'Luxembourg City',
#  'Lviv, Ukraine',
#  'Lyon, France',
#  'Madrid, Spain',
#  'Manchester, UK',
#  'Marseille, France',
#  'Milan, Italy',
#  'Montpellier, France',
#  'Munich, Germany',
#  'Nantes, France',
#  'Newcastle, UK',
#  'Nice, France',
#  'Nottingham, UK',
#  'Nuremberg, Germany',
#  'Oxford, UK',
#  'Paris, France',
#  'Prague, Czechia',
#  'Rennes, France',
#  'Rome, Italy',
#  'Rotterdam, Netherlands',
#  'Salzburg, Austria',
#  'Sheffield, UK',
#  'Southampton, UK',
#  'Strasbourg, France',
#  'Stuttgart, Germany',
#  'Toulouse, France',
#  'Turin, Italy',
#  'Utrecht, Netherlands',
#  'Valencia, Spain',
#  'Vienna, Austria',
#  'Warsaw, Poland',
#  'Zagreb, Croatia',
#  'Zurich, Switzerland'}
